# %% [markdown]
# # Google Dialogflow Chatbot

# %% [markdown]
# ## 1. Google Dialogflow Chatbot

# %% [markdown]
# ![Google%20Dialogflow.jpg](attachment:Google%20Dialogflow.jpg)

# %% [markdown]
# ## 2. Telegram Chatbot - (NadeemTelegramBot)

# %% [markdown]
# ![Telegram%20Chatbot.jpg](attachment:Telegram%20Chatbot.jpg)
